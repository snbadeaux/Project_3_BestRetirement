# %%
# Import python modules and packages
import csv
import pandas as pd
import re

# %%
# Read in the raw data from the .csv file for the nursing homes and performance
nursing_df = pd.read_csv('../Resources/Provider_Info.csv')

# Verify the data was imported
print(f'Shape of DataFrame: {nursing_df.shape}')
nursing_df
# Out:
# Shape of DataFrame: (15640, 82)
#        index Federal Provider Number  \
# 0          0                  015019
# 1          1                  015113
# 2          2                  015112
# 3          3                  015114
# 4          4                  015123
# ...      ...                     ...
# 15635  15635                  676372
# 15636  15636                  676367
# 15637  15637                  676391
# 15638  15638                  676377
# 15639  15639                  676382
#
#                                            Provider Name  \
# 0        MERRY WOOD LODGE CARE AND REHABILITATION CENTER
# 1                                      RIVER CITY CENTER
# 2        MAGNOLIA HAVEN HEALTH AND REHABILITATION CENTER
# 3                         SHADESCREST HEALTH CARE CENTER
# 4                         WASHINGTON COUNTY NURSING HOME
# ...                                                  ...
# 15635  TWIN PINES NORTH NURSING AND REHABILITATION CE...
# 15636                            BELTERRA HEALTH & REHAB
# 15637                                   WINDSOR CALALLEN
# 15638                           RELIANT DALLAS SUB-ACUTE
# 15639                        FALCON RIDGE REHABILITATION
#
#                        Provider Address   Provider City Provider State  \
# 0                           P O BOX 130          ELMORE             AL
# 1      1350 FOURTEENTH AVENUE SOUTHEAST         DECATUR             AL
# 2                     603 WRIGHT STREET        TUSKEGEE             AL
# 3                  331 WEST 25TH STREET          JASPER             AL
# 4              14600 ST STEPHENS AVENUE          CHATOM             AL
# ...                                 ...             ...            ...
# 15635               1301 MALLETTE DRIVE        VICTORIA             TX
# 15636      2170 NORTH LAKE FOREST DRIVE        MCKINNEY             TX
# 15637                   4162 WILDCAT DR  CORPUS CHRISTI             TX
# 15638               7930 NORTHAVEN ROAD          DALLAS             TX
# 15639              149 KLATTENHOFF LANE           HUTTO             TX
#
#        Provider Zip Code  Provider Phone Number  Provider SSA County Code  \
# 0                  36025             3345678484                       250
# 1                  35601             2563556911                       510
# 2                  36083             3347274960                       430
# 3                  35502             2053849086                       630
# 4                  36518             2518476412                       640
# ...                  ...                    ...                       ...
# 15635              77904             3615769454                       948
# 15636              75071             9725425500                       310
# 15637              78410             3612412954                       830
# 15638              75230             2147068230                       390
# 15639              78634             5128407000                       970
#
#       Provider County Name  ... Cycle 3 Total Health Score  \
# 0                   Elmore  ...                       24.0
# 1                   Morgan  ...                       40.0
# 2                    Macon  ...                       16.0
# 3                   Walker  ...                       52.0
# 4               Washington  ...                       20.0
# ...                    ...  ...                        ...
# 15635             Victoria  ...                        NaN
# 15636               Collin  ...                        NaN
# 15637               Nueces  ...                        NaN
# 15638               Dallas  ...                        NaN
# 15639           Williamson  ...                        NaN
#
#        Total Weighted Health Survey Score  \
# 0                                  22.667
# 1                                  48.667
# 2                                  15.333
# 3                                  25.333
# 4                                  13.333
# ...                                   ...
# 15635                               9.600
# 15636                              24.000
# 15637                                 NaN
# 15638                                 NaN
# 15639                              24.000
#
#        Number of Facility Reported Incidents  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 15635                                      1
# 15636                                      0
# 15637                                      0
# 15638                                      0
# 15639                                      0
#
#       Number of Substantiated Complaints  Number of Fines  \
# 0                                      1                1
# 1                                      3                1
# 2                                      0                0
# 3                                      3                1
# 4                                      0                0
# ...                                  ...              ...
# 15635                                  0                0
# 15636                                  0                0
# 15637                                  0                0
# 15638                                  0                0
# 15639                                  0                0
#
#       Total Amount of Fines in Dollars Number of Payment Denials  \
# 0                             $6692.00                         0
# 1                             $6045.00                         0
# 2                                $0.00                         0
# 3                           $189763.00                         0
# 4                                $0.00                         0
# ...                                ...                       ...
# 15635                            $0.00                         0
# 15636                            $0.00                         0
# 15637                            $0.00                         0
# 15638                            $0.00                         0
# 15639                            $0.00                         0
#
#        Total Number of Penalties  \
# 0                              1
# 1                              1
# 2                              0
# 3                              1
# 4                              0
# ...                          ...
# 15635                          0
# 15636                          0
# 15637                          0
# 15638                          0
# 15639                          0
#
#                                                 Location  Processing Date
# 0                             130 ELMORE\r\nAL 36025\r\n       09/01/2016
# 1      1350 FOURTEENTH AVENUE SOUTHEAST\r\nDECATUR, A...       09/01/2016
# 2      603 WRIGHT STREET\r\nTUSKEGEE, AL 36083\r\n(32...       09/01/2016
# 3      331 WEST 25TH STREET\r\nJASPER, AL 35502\r\n(3...       09/01/2016
# 4      14600 ST STEPHENS AVENUE\r\nCHATOM, AL 36518\r...       09/01/2016
# ...                                                  ...              ...
# 15635  1301 MALLETTE DRIVE\r\nVICTORIA, TX 77904\r\n(...       09/01/2016
# 15636  2170 NORTH LAKE FOREST DRIVE\r\nMCKINNEY, TX 7...       09/01/2016
# 15637  4162 WILDCAT DR\r\nCORPUS CHRISTI, TX 78410\r\...       09/01/2016
# 15638  7930 NORTHAVEN ROAD\r\nDALLAS, TX 75230\r\n(32...       09/01/2016
# 15639  149 KLATTENHOFF LANE\r\nHUTTO, TX 78634\r\n(30...       09/01/2016
#
# [15640 rows x 82 columns]

# %%
# Testing for duplicate rows
print(f'Initial number of rows: {nursing_df.shape[0]}')
nursing_df = nursing_df.drop_duplicates()
print(f'Number of rows after dropping duplicate rows: {nursing_df.shape[0]}')
# Out:
# Initial number of rows: 15640
# Number of rows after dropping duplicate rows: 15640

# %%
# Testing for uniqueness of 'Federal Provider Number'
print(f'Number of rows: {nursing_df.shape[0]}')
print(f'Number of unique "Federal Provider Number"s: {len(nursing_df["Federal Provider Number"].unique())}')
# Out:
# Number of rows: 15640
# Number of unique "Federal Provider Number"s: 15640

# %%
# Because the the resulting numbers are the same in the cell above, we can conclude that there are no 
# duplicate "Federal Provider Number"s and so it can be used as a primary key.

# %%
# Show all the columns
nursing_df.columns
# Out:
# Index(['index', 'Federal Provider Number', 'Provider Name', 'Provider Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Provider Phone Number', 'Provider SSA County Code',
#        'Provider County Name', 'Ownership Type', 'Number of Certified Beds',
#        'Number of Residents in Certified Beds', 'Provider Type',
#        'Provider Resides in Hospital', 'Legal Business Name',
#        'Date First Approved to Provide Medicare and Medicaid services',
#        'Continuing Care Retirement Community', 'Special Focus Facility',
#        'Most Recent Health Inspection More Than 2 Years Ago',
#        'Provider Changed Ownership in Last 12 Months',
#        'With a Resident and Family Council',
#        'Automatic Sprinkler Systems in All Required Areas', 'Overall Rating',
#        'Overall Rating Footnote', 'Health Inspection Rating',
#        'Health Inspection Rating Footnote', 'QM Rating', 'QM Rating Footnote',
#        'Staffing Rating', 'Staffing Rating Footnote', 'RN Staffing Rating',
#        'RN Staffing Rating Footnote', 'Reported Staffing Footnote',
#        'Physical Therapist Staffing Footnote',
#        'Reported CNA Staffing Hours per Resident per Day',
#        'Reported LPN Staffing Hours per Resident per Day',
#        'Reported RN Staffing Hours per Resident per Day',
#        'Reported Licensed Staffing Hours per Resident per Day',
#        'Reported Total Nurse Staffing Hours per Resident per Day',
#        'Reported Physical Therapist Staffing Hours per Resident Per Day',
#        'Expected CNA Staffing Hours per Resident per Day',
#        'Expected LPN Staffing Hours per Resident per Day',
#        'Expected RN Staffing Hours per Resident per Day',
#        'Expected Total Nurse Staffing Hours per Resident per Day',
#        'Adjusted CNA Staffing Hours per Resident per Day',
#        'Adjusted LPN Staffing Hours per Resident per Day',
#        'Adjusted RN Staffing Hours per Resident per Day',
#        'Adjusted Total Nurse Staffing Hours per Resident per Day',
#        'Cycle 1 Total Number of Health Deficiencies',
#        'Cycle 1 Number of Standard Health Deficiencies',
#        'Cycle 1 Number of Complaint Health Deficiencies',
#        'Cycle 1 Health Deficiency Score',
#        'Cycle 1 Standard Survey Health Date',
#        'Cycle 1 Number of Health Revisits', 'Cycle 1 Health Revisit Score',
#        'Cycle 1 Total Health Score',
#        'Cycle 2 Total Number of Health Deficiencies',
#        'Cycle 2 Number of Standard Health Deficiencies',
#        'Cycle 2 Number of Complaint Health Deficiencies',
#        'Cycle 2 Health Deficiency Score',
#        'Cycle 2 Standard Health Survey Date',
#        'Cycle 2 Number of Health Revisits', 'Cycle 2 Health Revisit Score',
#        'Cycle 2 Total Health Score',
#        'Cycle 3 Total Number of Health Deficiencies',
#        'Cycle 3 Number of Standard Health Deficiencies',
#        'Cycle 3 Number of Complaint Health Deficiencies',
#        'Cycle 3 Health Deficiency Score',
#        'Cycle 3 Standard Health Survey Date',
#        'Cycle 3 Number of Health Revisits', 'Cycle 3 Health Revisit Score',
#        'Cycle 3 Total Health Score', 'Total Weighted Health Survey Score',
#        'Number of Facility Reported Incidents',
#        'Number of Substantiated Complaints', 'Number of Fines',
#        'Total Amount of Fines in Dollars', 'Number of Payment Denials',
#        'Total Number of Penalties', 'Location', 'Processing Date'],
#       dtype='object')

# %%
# Investigate the types of the columns that are present
nursing_df.dtypes
# Out:
# index                                int64
# Federal Provider Number             object
# Provider Name                       object
# Provider Address                    object
# Provider City                       object
#                                      ...
# Total Amount of Fines in Dollars    object
# Number of Payment Denials            int64
# Total Number of Penalties            int64
# Location                            object
# Processing Date                     object
# Length: 82, dtype: object

# %%
# Investigate the count of non-nan values for the columns
print(nursing_df.count().loc[nursing_df.count() < nursing_df.shape[0]])
# Out:
# Overall Rating                                                     15505
# Overall Rating Footnote                                              135
# Health Inspection Rating                                           15505
# Health Inspection Rating Footnote                                    135
# QM Rating                                                          15477
# QM Rating Footnote                                                   163
# Staffing Rating                                                    15198
# Staffing Rating Footnote                                             442
# RN Staffing Rating                                                 15198
# RN Staffing Rating Footnote                                          442
# Reported Staffing Footnote                                           396
# Physical Therapist Staffing Footnote                                 398
# Reported CNA Staffing Hours per Resident per Day                   15244
# Reported LPN Staffing Hours per Resident per Day                   15244
# Reported RN Staffing Hours per Resident per Day                    15244
# Reported Licensed Staffing Hours per Resident per Day              15244
# Reported Total Nurse Staffing Hours per Resident per Day           15244
# Reported Physical Therapist Staffing Hours per Resident Per Day    15242
# Expected CNA Staffing Hours per Resident per Day                   15571
# Expected LPN Staffing Hours per Resident per Day                   15571
# Expected RN Staffing Hours per Resident per Day                    15571
# Expected Total Nurse Staffing Hours per Resident per Day           15571
# Adjusted CNA Staffing Hours per Resident per Day                   15198
# Adjusted LPN Staffing Hours per Resident per Day                   15198
# Adjusted RN Staffing Hours per Resident per Day                    15198
# Adjusted Total Nurse Staffing Hours per Resident per Day           15198
# Cycle 1 Total Number of Health Deficiencies                        15505
# Cycle 1 Number of Standard Health Deficiencies                     15505
# Cycle 1 Number of Complaint Health Deficiencies                    15505
# Cycle 1 Health Deficiency Score                                    15505
# Cycle 1 Standard Survey Health Date                                15505
# Cycle 1 Number of Health Revisits                                  15505
# Cycle 1 Health Revisit Score                                       15505
# Cycle 1 Total Health Score                                         15505
# Cycle 2 Total Number of Health Deficiencies                        15505
# Cycle 2 Number of Standard Health Deficiencies                     15505
# Cycle 2 Number of Complaint Health Deficiencies                    15505
# Cycle 2 Health Deficiency Score                                    15505
# Cycle 2 Standard Health Survey Date                                15505
# Cycle 2 Number of Health Revisits                                  15505
# Cycle 2 Health Revisit Score                                       15505
# Cycle 2 Total Health Score                                         15505
# Cycle 3 Total Number of Health Deficiencies                        15362
# Cycle 3 Number of Standard Health Deficiencies                     15362
# Cycle 3 Number of Complaint Health Deficiencies                    15362
# Cycle 3 Health Deficiency Score                                    15362
# Cycle 3 Standard Health Survey Date                                15362
# Cycle 3 Number of Health Revisits                                  15362
# Cycle 3 Health Revisit Score                                       15362
# Cycle 3 Total Health Score                                         15362
# Total Weighted Health Survey Score                                 15505
# Location                                                           15613
# dtype: int64

# %%
# Because location plays an important role in decision making for all sorts of reasons
# (e.g. weather, taxes, large city or rural area, proximity to family, ... etc.), any 
# nursing home without a location associated with it will be dropped from consideration
no_nan_n_df = nursing_df.dropna(subset = ['Location'])
no_nan_n_df.count()
# Out:
# index                               15613
# Federal Provider Number             15613
# Provider Name                       15613
# Provider Address                    15613
# Provider City                       15613
#                                     ...
# Total Amount of Fines in Dollars    15613
# Number of Payment Denials           15613
# Total Number of Penalties           15613
# Location                            15613
# Processing Date                     15613
# Length: 82, dtype: int64

# %%
# Extract coordinates from the 'Location' column and insert 'Null' if there are no
# coordinates listed for a location.
coord_n_df = no_nan_n_df.copy()
coord_n_df['Coordinates'] = [re.search('\([-]?\d+\.\d+, [-]?\d+\.\d+\)', row).group() if len(re.findall('\([-]?\d+\.\d+, [-]?\d+\.\d+\)', row)) > 0 else 'Null' for row in no_nan_n_df['Location'] ]

# %%
# Verify that the column Coordinates was added
print(coord_n_df.shape)
coord_n_df[['Federal Provider Number', 'Location', 'Coordinates']]
# Out:
# (15613, 83)
#       Federal Provider Number  \
# 0                      015019
# 1                      015113
# 2                      015112
# 3                      015114
# 4                      015123
# ...                       ...
# 15635                  676372
# 15636                  676367
# 15637                  676391
# 15638                  676377
# 15639                  676382
#
#                                                 Location  \
# 0                             130 ELMORE\r\nAL 36025\r\n
# 1      1350 FOURTEENTH AVENUE SOUTHEAST\r\nDECATUR, A...
# 2      603 WRIGHT STREET\r\nTUSKEGEE, AL 36083\r\n(32...
# 3      331 WEST 25TH STREET\r\nJASPER, AL 35502\r\n(3...
# 4      14600 ST STEPHENS AVENUE\r\nCHATOM, AL 36518\r...
# ...                                                  ...
# 15635  1301 MALLETTE DRIVE\r\nVICTORIA, TX 77904\r\n(...
# 15636  2170 NORTH LAKE FOREST DRIVE\r\nMCKINNEY, TX 7...
# 15637  4162 WILDCAT DR\r\nCORPUS CHRISTI, TX 78410\r\...
# 15638  7930 NORTHAVEN ROAD\r\nDALLAS, TX 75230\r\n(32...
# 15639  149 KLATTENHOFF LANE\r\nHUTTO, TX 78634\r\n(30...
#
#                    Coordinates
# 0                         Null
# 1       (34.58636, -86.970399)
# 2      (32.432923, -85.691051)
# 3      (33.826573, -87.279027)
# 4      (31.460032, -88.234524)
# ...                        ...
# 15635  (28.869706, -97.011339)
# 15636  (33.218111, -96.679208)
# 15637  (27.858891, -97.633984)
# 15638  (32.901603, -96.770271)
# 15639  (30.511969, -97.579603)
#
# [15613 rows x 3 columns]

# %%
# Remove all rows that have a 'Null' for their 'Coordinates' value primarily b/c
# the time comsumed for tracking down why coordinates couldn't be determined is beyond
# the limits of this project's time horizon.
coord_n_df = coord_n_df.loc[coord_n_df['Coordinates'] != 'Null']

#Verify the any 'Null' Location rows were removed
print(coord_n_df.shape)
coord_n_df.reset_index(inplace=True)
coord_n_df.head(10)
# Out:
# (15119, 83)
#    level_0  index Federal Provider Number  \
# 0        1      1                  015113
# 1        2      2                  015112
# 2        3      3                  015114
# 3        4      4                  015123
# 4        5      5                  015115
# 5        6      6                  015116
# 6        7      7                  015138
# 7        8      8                  015137
# 8        9      9                  015136
# 9       10     10                  015151
#
#                                      Provider Name  \
# 0                                RIVER CITY CENTER
# 1  MAGNOLIA HAVEN HEALTH AND REHABILITATION CENTER
# 2                   SHADESCREST HEALTH CARE CENTER
# 3                   WASHINGTON COUNTY NURSING HOME
# 4           CORDOVA HEALTH AND REHABILITATION, LLC
# 5       SIGNATURE HEALTHCARE OF WHITESBURG GARDENS
# 6                HENDRIX HEALTH AND REHABILITATION
# 7                    ALICEVILLE MANOR NURSING HOME
# 8                     FALKVILLE HEALTH CARE CENTER
# 9                         AZALEA GARDENS OF MOBILE
#
#                    Provider Address   Provider City Provider State  \
# 0  1350 FOURTEENTH AVENUE SOUTHEAST         DECATUR             AL
# 1                 603 WRIGHT STREET        TUSKEGEE             AL
# 2              331 WEST 25TH STREET          JASPER             AL
# 3          14600 ST STEPHENS AVENUE          CHATOM             AL
# 4           70 HIGHLAND STREET WEST         CORDOVA             AL
# 5             105 TEAKWOOD DRIVE SW      HUNTSVILLE             AL
# 6                   1000 HIGHWAY 33  DOUBLE SPRINGS             AL
# 7         703 17TH STREET NORTHWEST      ALICEVILLE             AL
# 8    10 WEST 3RD STREET  PO BOX 409       FALKVILLE             AL
# 9               1758 SPRINGHILL AVE          MOBILE             AL
#
#    Provider Zip Code  Provider Phone Number  Provider SSA County Code  ...  \
# 0              35601             2563556911                       510  ...
# 1              36083             3347274960                       430  ...
# 2              35502             2053849086                       630  ...
# 3              36518             2518476412                       640  ...
# 4              35550             2054839282                       630  ...
# 5              35801             2568815000                       440  ...
# 6              35553             2054892136                       660  ...
# 7              35442             2053736307                       530  ...
# 8              35622             2567845291                       510  ...
# 9              36607             2514790551                       480  ...
#
#   Total Weighted Health Survey Score Number of Facility Reported Incidents  \
# 0                             48.667                                     0
# 1                             15.333                                     0
# 2                             25.333                                     0
# 3                             13.333                                     0
# 4                             32.667                                     0
# 5                             52.000                                     0
# 6                             14.667                                     0
# 7                              5.333                                     0
# 8                             23.333                                     0
# 9                             44.667                                     0
#
#    Number of Substantiated Complaints  Number of Fines  \
# 0                                   3                1
# 1                                   0                0
# 2                                   3                1
# 3                                   0                0
# 4                                   0                0
# 5                                   1                0
# 6                                   0                0
# 7                                   0                0
# 8                                   1                0
# 9                                   2                1
#
#   Total Amount of Fines in Dollars  Number of Payment Denials  \
# 0                         $6045.00                          0
# 1                            $0.00                          0
# 2                       $189763.00                          0
# 3                            $0.00                          0
# 4                            $0.00                          0
# 5                            $0.00                          0
# 6                            $0.00                          0
# 7                            $0.00                          0
# 8                            $0.00                          0
# 9                         $6500.00                          0
#
#   Total Number of Penalties  \
# 0                         1
# 1                         0
# 2                         1
# 3                         0
# 4                         0
# 5                         0
# 6                         0
# 7                         0
# 8                         0
# 9                         1
#
#                                             Location  Processing Date  \
# 0  1350 FOURTEENTH AVENUE SOUTHEAST\r\nDECATUR, A...       09/01/2016
# 1  603 WRIGHT STREET\r\nTUSKEGEE, AL 36083\r\n(32...       09/01/2016
# 2  331 WEST 25TH STREET\r\nJASPER, AL 35502\r\n(3...       09/01/2016
# 3  14600 ST STEPHENS AVENUE\r\nCHATOM, AL 36518\r...       09/01/2016
# 4  70 HIGHLAND STREET WEST\r\nCORDOVA, AL 35550\r...       09/01/2016
# 5  105 TEAKWOOD DRIVE SW\r\nHUNTSVILLE, AL 35801\...       09/01/2016
# 6  1000 HIGHWAY\r\nDOUBLE SPRINGS, AL 35553\r\n(3...       09/01/2016
# 7  703 17TH STREET NORTHWEST\r\nALICEVILLE, AL 35...       09/01/2016
# 8  10 WEST 3RD STREET\r\nFALKVILLE, AL 35622\r\n(...       09/01/2016
# 9  1758 SPRINGHILL AVE\r\nMOBILE, AL 36607\r\n(30...       09/01/2016
#
#                Coordinates
# 0   (34.58636, -86.970399)
# 1  (32.432923, -85.691051)
# 2  (33.826573, -87.279027)
# 3  (31.460032, -88.234524)
# 4  (33.762149, -87.184514)
# 5  (34.697369, -86.570383)
# 6  (34.163162, -87.409783)
# 7   (33.134382, -88.16865)
# 8  (34.368669, -86.910173)
# 9  (30.691974, -88.082071)
#
# [10 rows x 84 columns]

# %%
# Remove extra column created by reset_index
del coord_n_df['level_0']
coord_n_df
# Out:
#        index Federal Provider Number  \
# 0          1                  015113
# 1          2                  015112
# 2          3                  015114
# 3          4                  015123
# 4          5                  015115
# ...      ...                     ...
# 15114  15635                  676372
# 15115  15636                  676367
# 15116  15637                  676391
# 15117  15638                  676377
# 15118  15639                  676382
#
#                                            Provider Name  \
# 0                                      RIVER CITY CENTER
# 1        MAGNOLIA HAVEN HEALTH AND REHABILITATION CENTER
# 2                         SHADESCREST HEALTH CARE CENTER
# 3                         WASHINGTON COUNTY NURSING HOME
# 4                 CORDOVA HEALTH AND REHABILITATION, LLC
# ...                                                  ...
# 15114  TWIN PINES NORTH NURSING AND REHABILITATION CE...
# 15115                            BELTERRA HEALTH & REHAB
# 15116                                   WINDSOR CALALLEN
# 15117                           RELIANT DALLAS SUB-ACUTE
# 15118                        FALCON RIDGE REHABILITATION
#
#                        Provider Address   Provider City Provider State  \
# 0      1350 FOURTEENTH AVENUE SOUTHEAST         DECATUR             AL
# 1                     603 WRIGHT STREET        TUSKEGEE             AL
# 2                  331 WEST 25TH STREET          JASPER             AL
# 3              14600 ST STEPHENS AVENUE          CHATOM             AL
# 4               70 HIGHLAND STREET WEST         CORDOVA             AL
# ...                                 ...             ...            ...
# 15114               1301 MALLETTE DRIVE        VICTORIA             TX
# 15115      2170 NORTH LAKE FOREST DRIVE        MCKINNEY             TX
# 15116                   4162 WILDCAT DR  CORPUS CHRISTI             TX
# 15117               7930 NORTHAVEN ROAD          DALLAS             TX
# 15118              149 KLATTENHOFF LANE           HUTTO             TX
#
#        Provider Zip Code  Provider Phone Number  Provider SSA County Code  \
# 0                  35601             2563556911                       510
# 1                  36083             3347274960                       430
# 2                  35502             2053849086                       630
# 3                  36518             2518476412                       640
# 4                  35550             2054839282                       630
# ...                  ...                    ...                       ...
# 15114              77904             3615769454                       948
# 15115              75071             9725425500                       310
# 15116              78410             3612412954                       830
# 15117              75230             2147068230                       390
# 15118              78634             5128407000                       970
#
#       Provider County Name  ... Total Weighted Health Survey Score  \
# 0                   Morgan  ...                             48.667
# 1                    Macon  ...                             15.333
# 2                   Walker  ...                             25.333
# 3               Washington  ...                             13.333
# 4                   Walker  ...                             32.667
# ...                    ...  ...                                ...
# 15114             Victoria  ...                              9.600
# 15115               Collin  ...                             24.000
# 15116               Nueces  ...                                NaN
# 15117               Dallas  ...                                NaN
# 15118           Williamson  ...                             24.000
#
#        Number of Facility Reported Incidents  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
# ...                                      ...
# 15114                                      1
# 15115                                      0
# 15116                                      0
# 15117                                      0
# 15118                                      0
#
#        Number of Substantiated Complaints Number of Fines  \
# 0                                       3               1
# 1                                       0               0
# 2                                       3               1
# 3                                       0               0
# 4                                       0               0
# ...                                   ...             ...
# 15114                                   0               0
# 15115                                   0               0
# 15116                                   0               0
# 15117                                   0               0
# 15118                                   0               0
#
#        Total Amount of Fines in Dollars Number of Payment Denials  \
# 0                              $6045.00                         0
# 1                                 $0.00                         0
# 2                            $189763.00                         0
# 3                                 $0.00                         0
# 4                                 $0.00                         0
# ...                                 ...                       ...
# 15114                             $0.00                         0
# 15115                             $0.00                         0
# 15116                             $0.00                         0
# 15117                             $0.00                         0
# 15118                             $0.00                         0
#
#       Total Number of Penalties  \
# 0                             1
# 1                             0
# 2                             1
# 3                             0
# 4                             0
# ...                         ...
# 15114                         0
# 15115                         0
# 15116                         0
# 15117                         0
# 15118                         0
#
#                                                 Location  Processing Date  \
# 0      1350 FOURTEENTH AVENUE SOUTHEAST\r\nDECATUR, A...       09/01/2016
# 1      603 WRIGHT STREET\r\nTUSKEGEE, AL 36083\r\n(32...       09/01/2016
# 2      331 WEST 25TH STREET\r\nJASPER, AL 35502\r\n(3...       09/01/2016
# 3      14600 ST STEPHENS AVENUE\r\nCHATOM, AL 36518\r...       09/01/2016
# 4      70 HIGHLAND STREET WEST\r\nCORDOVA, AL 35550\r...       09/01/2016
# ...                                                  ...              ...
# 15114  1301 MALLETTE DRIVE\r\nVICTORIA, TX 77904\r\n(...       09/01/2016
# 15115  2170 NORTH LAKE FOREST DRIVE\r\nMCKINNEY, TX 7...       09/01/2016
# 15116  4162 WILDCAT DR\r\nCORPUS CHRISTI, TX 78410\r\...       09/01/2016
# 15117  7930 NORTHAVEN ROAD\r\nDALLAS, TX 75230\r\n(32...       09/01/2016
# 15118  149 KLATTENHOFF LANE\r\nHUTTO, TX 78634\r\n(30...       09/01/2016
#
#                    Coordinates
# 0       (34.58636, -86.970399)
# 1      (32.432923, -85.691051)
# 2      (33.826573, -87.279027)
# 3      (31.460032, -88.234524)
# 4      (33.762149, -87.184514)
# ...                        ...
# 15114  (28.869706, -97.011339)
# 15115  (33.218111, -96.679208)
# 15116  (27.858891, -97.633984)
# 15117  (32.901603, -96.770271)
# 15118  (30.511969, -97.579603)
#
# [15119 rows x 83 columns]

# %%
# Extract the Latitude from the Coordinates column and create a Latitude column with the value
# extracted
coord_n_df['Latitude'] = [re.search('[-]?\d+\.\d+', row).group() for row in coord_n_df['Coordinates']]
coord_n_df.head()
coord_n_df[['Federal Provider Number', 'Location', 'Coordinates', 'Latitude']]
# Out:
#       Federal Provider Number  \
# 0                      015113
# 1                      015112
# 2                      015114
# 3                      015123
# 4                      015115
# ...                       ...
# 15114                  676372
# 15115                  676367
# 15116                  676391
# 15117                  676377
# 15118                  676382
#
#                                                 Location  \
# 0      1350 FOURTEENTH AVENUE SOUTHEAST\r\nDECATUR, A...
# 1      603 WRIGHT STREET\r\nTUSKEGEE, AL 36083\r\n(32...
# 2      331 WEST 25TH STREET\r\nJASPER, AL 35502\r\n(3...
# 3      14600 ST STEPHENS AVENUE\r\nCHATOM, AL 36518\r...
# 4      70 HIGHLAND STREET WEST\r\nCORDOVA, AL 35550\r...
# ...                                                  ...
# 15114  1301 MALLETTE DRIVE\r\nVICTORIA, TX 77904\r\n(...
# 15115  2170 NORTH LAKE FOREST DRIVE\r\nMCKINNEY, TX 7...
# 15116  4162 WILDCAT DR\r\nCORPUS CHRISTI, TX 78410\r\...
# 15117  7930 NORTHAVEN ROAD\r\nDALLAS, TX 75230\r\n(32...
# 15118  149 KLATTENHOFF LANE\r\nHUTTO, TX 78634\r\n(30...
#
#                    Coordinates   Latitude
# 0       (34.58636, -86.970399)   34.58636
# 1      (32.432923, -85.691051)  32.432923
# 2      (33.826573, -87.279027)  33.826573
# 3      (31.460032, -88.234524)  31.460032
# 4      (33.762149, -87.184514)  33.762149
# ...                        ...        ...
# 15114  (28.869706, -97.011339)  28.869706
# 15115  (33.218111, -96.679208)  33.218111
# 15116  (27.858891, -97.633984)  27.858891
# 15117  (32.901603, -96.770271)  32.901603
# 15118  (30.511969, -97.579603)  30.511969
#
# [15119 rows x 4 columns]

# %%
# Extract the Longitude from the Coordinates column and create a Longitude column with the value
# extracted
coord_n_df['Longitude'] = [re.findall('[-]?\d+\.\d+', row)[1] for row in coord_n_df['Coordinates']]
print(coord_n_df.shape)
coord_n_df[['Federal Provider Number', 'Location', 'Coordinates', 'Latitude', 'Longitude']]
# Out:
# (15119, 85)
#       Federal Provider Number  \
# 0                      015113
# 1                      015112
# 2                      015114
# 3                      015123
# 4                      015115
# ...                       ...
# 15114                  676372
# 15115                  676367
# 15116                  676391
# 15117                  676377
# 15118                  676382
#
#                                                 Location  \
# 0      1350 FOURTEENTH AVENUE SOUTHEAST\r\nDECATUR, A...
# 1      603 WRIGHT STREET\r\nTUSKEGEE, AL 36083\r\n(32...
# 2      331 WEST 25TH STREET\r\nJASPER, AL 35502\r\n(3...
# 3      14600 ST STEPHENS AVENUE\r\nCHATOM, AL 36518\r...
# 4      70 HIGHLAND STREET WEST\r\nCORDOVA, AL 35550\r...
# ...                                                  ...
# 15114  1301 MALLETTE DRIVE\r\nVICTORIA, TX 77904\r\n(...
# 15115  2170 NORTH LAKE FOREST DRIVE\r\nMCKINNEY, TX 7...
# 15116  4162 WILDCAT DR\r\nCORPUS CHRISTI, TX 78410\r\...
# 15117  7930 NORTHAVEN ROAD\r\nDALLAS, TX 75230\r\n(32...
# 15118  149 KLATTENHOFF LANE\r\nHUTTO, TX 78634\r\n(30...
#
#                    Coordinates   Latitude   Longitude
# 0       (34.58636, -86.970399)   34.58636  -86.970399
# 1      (32.432923, -85.691051)  32.432923  -85.691051
# 2      (33.826573, -87.279027)  33.826573  -87.279027
# 3      (31.460032, -88.234524)  31.460032  -88.234524
# 4      (33.762149, -87.184514)  33.762149  -87.184514
# ...                        ...        ...         ...
# 15114  (28.869706, -97.011339)  28.869706  -97.011339
# 15115  (33.218111, -96.679208)  33.218111  -96.679208
# 15116  (27.858891, -97.633984)  27.858891  -97.633984
# 15117  (32.901603, -96.770271)  32.901603  -96.770271
# 15118  (30.511969, -97.579603)  30.511969  -97.579603
#
# [15119 rows x 5 columns]

# %%
# State the number of columns before deleting a column, so as to verify the
# column deletion after the fact.
len(coord_n_df.columns)
# Out:
# 85

# %%
# Deleting the redundant Coordinates column (Latitude and Longitude columns
# make it redundant).
del coord_n_df['Coordinates']

# %%
# Verify that the column count reduced by 1
len(coord_n_df.columns)
# Out:
# 84

# %%
# Verify that the Coordinates column is gone and the rest of the dataframe is 
# unaffected
coord_n_df.head()
# Out:
#    index Federal Provider Number  \
# 0      1                  015113
# 1      2                  015112
# 2      3                  015114
# 3      4                  015123
# 4      5                  015115
#
#                                      Provider Name  \
# 0                                RIVER CITY CENTER
# 1  MAGNOLIA HAVEN HEALTH AND REHABILITATION CENTER
# 2                   SHADESCREST HEALTH CARE CENTER
# 3                   WASHINGTON COUNTY NURSING HOME
# 4           CORDOVA HEALTH AND REHABILITATION, LLC
#
#                    Provider Address Provider City Provider State  \
# 0  1350 FOURTEENTH AVENUE SOUTHEAST       DECATUR             AL
# 1                 603 WRIGHT STREET      TUSKEGEE             AL
# 2              331 WEST 25TH STREET        JASPER             AL
# 3          14600 ST STEPHENS AVENUE        CHATOM             AL
# 4           70 HIGHLAND STREET WEST       CORDOVA             AL
#
#    Provider Zip Code  Provider Phone Number  Provider SSA County Code  \
# 0              35601             2563556911                       510
# 1              36083             3347274960                       430
# 2              35502             2053849086                       630
# 3              36518             2518476412                       640
# 4              35550             2054839282                       630
#
#   Provider County Name  ... Number of Facility Reported Incidents  \
# 0               Morgan  ...                                     0
# 1                Macon  ...                                     0
# 2               Walker  ...                                     0
# 3           Washington  ...                                     0
# 4               Walker  ...                                     0
#
#    Number of Substantiated Complaints  Number of Fines  \
# 0                                   3                1
# 1                                   0                0
# 2                                   3                1
# 3                                   0                0
# 4                                   0                0
#
#   Total Amount of Fines in Dollars  Number of Payment Denials  \
# 0                         $6045.00                          0
# 1                            $0.00                          0
# 2                       $189763.00                          0
# 3                            $0.00                          0
# 4                            $0.00                          0
#
#   Total Number of Penalties  \
# 0                         1
# 1                         0
# 2                         1
# 3                         0
# 4                         0
#
#                                             Location  Processing Date  \
# 0  1350 FOURTEENTH AVENUE SOUTHEAST\r\nDECATUR, A...       09/01/2016
# 1  603 WRIGHT STREET\r\nTUSKEGEE, AL 36083\r\n(32...       09/01/2016
# 2  331 WEST 25TH STREET\r\nJASPER, AL 35502\r\n(3...       09/01/2016
# 3  14600 ST STEPHENS AVENUE\r\nCHATOM, AL 36518\r...       09/01/2016
# 4  70 HIGHLAND STREET WEST\r\nCORDOVA, AL 35550\r...       09/01/2016
#
#     Latitude   Longitude
# 0   34.58636  -86.970399
# 1  32.432923  -85.691051
# 2  33.826573  -87.279027
# 3  31.460032  -88.234524
# 4  33.762149  -87.184514
#
# [5 rows x 84 columns]

# %%
# Print all columns as an aid in deciding which columns to keep and which to
# truncate from the dataframe
print(len(coord_n_df.columns))
coord_n_df.columns
# Out:
# 84
# Index(['index', 'Federal Provider Number', 'Provider Name', 'Provider Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Provider Phone Number', 'Provider SSA County Code',
#        'Provider County Name', 'Ownership Type', 'Number of Certified Beds',
#        'Number of Residents in Certified Beds', 'Provider Type',
#        'Provider Resides in Hospital', 'Legal Business Name',
#        'Date First Approved to Provide Medicare and Medicaid services',
#        'Continuing Care Retirement Community', 'Special Focus Facility',
#        'Most Recent Health Inspection More Than 2 Years Ago',
#        'Provider Changed Ownership in Last 12 Months',
#        'With a Resident and Family Council',
#        'Automatic Sprinkler Systems in All Required Areas', 'Overall Rating',
#        'Overall Rating Footnote', 'Health Inspection Rating',
#        'Health Inspection Rating Footnote', 'QM Rating', 'QM Rating Footnote',
#        'Staffing Rating', 'Staffing Rating Footnote', 'RN Staffing Rating',
#        'RN Staffing Rating Footnote', 'Reported Staffing Footnote',
#        'Physical Therapist Staffing Footnote',
#        'Reported CNA Staffing Hours per Resident per Day',
#        'Reported LPN Staffing Hours per Resident per Day',
#        'Reported RN Staffing Hours per Resident per Day',
#        'Reported Licensed Staffing Hours per Resident per Day',
#        'Reported Total Nurse Staffing Hours per Resident per Day',
#        'Reported Physical Therapist Staffing Hours per Resident Per Day',
#        'Expected CNA Staffing Hours per Resident per Day',
#        'Expected LPN Staffing Hours per Resident per Day',
#        'Expected RN Staffing Hours per Resident per Day',
#        'Expected Total Nurse Staffing Hours per Resident per Day',
#        'Adjusted CNA Staffing Hours per Resident per Day',
#        'Adjusted LPN Staffing Hours per Resident per Day',
#        'Adjusted RN Staffing Hours per Resident per Day',
#        'Adjusted Total Nurse Staffing Hours per Resident per Day',
#        'Cycle 1 Total Number of Health Deficiencies',
#        'Cycle 1 Number of Standard Health Deficiencies',
#        'Cycle 1 Number of Complaint Health Deficiencies',
#        'Cycle 1 Health Deficiency Score',
#        'Cycle 1 Standard Survey Health Date',
#        'Cycle 1 Number of Health Revisits', 'Cycle 1 Health Revisit Score',
#        'Cycle 1 Total Health Score',
#        'Cycle 2 Total Number of Health Deficiencies',
#        'Cycle 2 Number of Standard Health Deficiencies',
#        'Cycle 2 Number of Complaint Health Deficiencies',
#        'Cycle 2 Health Deficiency Score',
#        'Cycle 2 Standard Health Survey Date',
#        'Cycle 2 Number of Health Revisits', 'Cycle 2 Health Revisit Score',
#        'Cycle 2 Total Health Score',
#        'Cycle 3 Total Number of Health Deficiencies',
#        'Cycle 3 Number of Standard Health Deficiencies',
#        'Cycle 3 Number of Complaint Health Deficiencies',
#        'Cycle 3 Health Deficiency Score',
#        'Cycle 3 Standard Health Survey Date',
#        'Cycle 3 Number of Health Revisits', 'Cycle 3 Health Revisit Score',
#        'Cycle 3 Total Health Score', 'Total Weighted Health Survey Score',
#        'Number of Facility Reported Incidents',
#        'Number of Substantiated Complaints', 'Number of Fines',
#        'Total Amount of Fines in Dollars', 'Number of Payment Denials',
#        'Total Number of Penalties', 'Location', 'Processing Date', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
# Remove extraneous columns
list_of_columns_to_keep = ['Federal Provider Number', 'Provider Name', 
    'Provider City', 'Provider State', 'Provider Zip Code', 'Provider County Name',
    'Ownership Type', 'Number of Certified Beds', 'Number of Residents in Certified Beds', 
    'Provider Type', 'Provider Resides in Hospital', 
    'Most Recent Health Inspection More Than 2 Years Ago', 
    'Automatic Sprinkler Systems in All Required Areas', 'Overall Rating',
    'Health Inspection Rating','Staffing Rating','RN Staffing Rating',
    'Total Weighted Health Survey Score','Number of Facility Reported Incidents',
    'Number of Substantiated Complaints', 'Number of Fines',
    'Total Amount of Fines in Dollars', 'Number of Payment Denials',
    'Total Number of Penalties', 'Location', 'Processing Date', 'Latitude',
    'Adjusted Total Nurse Staffing Hours per Resident per Day', 'Longitude']

truncated_nursing_df = pd.DataFrame()
truncated_nursing_df = coord_n_df[list_of_columns_to_keep]

# %%
# Assure that the columns to keep were kept and the columns to remove
# were removed
print(len(truncated_nursing_df.columns))
truncated_nursing_df.columns
# Out:
# 29
# Index(['Federal Provider Number', 'Provider Name', 'Provider City',
#        'Provider State', 'Provider Zip Code', 'Provider County Name',
#        'Ownership Type', 'Number of Certified Beds',
#        'Number of Residents in Certified Beds', 'Provider Type',
#        'Provider Resides in Hospital',
#        'Most Recent Health Inspection More Than 2 Years Ago',
#        'Automatic Sprinkler Systems in All Required Areas', 'Overall Rating',
#        'Health Inspection Rating', 'Staffing Rating', 'RN Staffing Rating',
#        'Total Weighted Health Survey Score',
#        'Number of Facility Reported Incidents',
#        'Number of Substantiated Complaints', 'Number of Fines',
#        'Total Amount of Fines in Dollars', 'Number of Payment Denials',
#        'Total Number of Penalties', 'Location', 'Processing Date', 'Latitude',
#        'Adjusted Total Nurse Staffing Hours per Resident per Day',
#        'Longitude'],
#       dtype='object')

# %%
# Calculating R Coefficients between columns
correlations_df = truncated_nursing_df.corr()
correlations_df
# Out:
# C:\Users\T852\AppData\Local\Temp\ipykernel_216972\3664722020.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations_df = truncated_nursing_df.corr()
#                                                     Provider Zip Code  \
# Provider Zip Code                                            1.000000
# Number of Certified Beds                                    -0.175971
# Number of Residents in Certified Beds                       -0.246064
# Provider Resides in Hospital                                 0.022419
# Most Recent Health Inspection More Than 2 Years...           0.000004
# Overall Rating                                               0.011350
# Health Inspection Rating                                    -0.001988
# Staffing Rating                                              0.019494
# RN Staffing Rating                                          -0.065033
# Total Weighted Health Survey Score                           0.198754
# Number of Facility Reported Incidents                        0.132162
# Number of Substantiated Complaints                           0.084715
# Number of Fines                                              0.038334
# Number of Payment Denials                                    0.114800
# Total Number of Penalties                                    0.073342
# Adjusted Total Nurse Staffing Hours per Residen...           0.092353
#
#                                                     Number of Certified Beds  \
# Provider Zip Code                                                  -0.175971
# Number of Certified Beds                                            1.000000
# Number of Residents in Certified Beds                               0.923585
# Provider Resides in Hospital                                       -0.148536
# Most Recent Health Inspection More Than 2 Years...                 -0.026011
# Overall Rating                                                     -0.177076
# Health Inspection Rating                                           -0.169983
# Staffing Rating                                                    -0.206938
# RN Staffing Rating                                                 -0.205187
# Total Weighted Health Survey Score                                  0.078245
# Number of Facility Reported Incidents                               0.091545
# Number of Substantiated Complaints                                  0.209582
# Number of Fines                                                     0.075043
# Number of Payment Denials                                           0.029804
# Total Number of Penalties                                           0.071583
# Adjusted Total Nurse Staffing Hours per Residen...                 -0.196783
#
#                                                     Number of Residents in Certified Beds  \
# Provider Zip Code                                                               -0.246064
# Number of Certified Beds                                                         0.923585
# Number of Residents in Certified Beds                                            1.000000
# Provider Resides in Hospital                                                    -0.140992
# Most Recent Health Inspection More Than 2 Years...                              -0.024258
# Overall Rating                                                                  -0.136609
# Health Inspection Rating                                                        -0.133849
# Staffing Rating                                                                 -0.205556
# RN Staffing Rating                                                              -0.198600
# Total Weighted Health Survey Score                                               0.028913
# Number of Facility Reported Incidents                                            0.082893
# Number of Substantiated Complaints                                               0.157475
# Number of Fines                                                                  0.043969
# Number of Payment Denials                                                       -0.011505
# Total Number of Penalties                                                        0.031244
# Adjusted Total Nurse Staffing Hours per Residen...                              -0.205458
#
#                                                     Provider Resides in Hospital  \
# Provider Zip Code                                                       0.022419
# Number of Certified Beds                                               -0.148536
# Number of Residents in Certified Beds                                  -0.140992
# Provider Resides in Hospital                                            1.000000
# Most Recent Health Inspection More Than 2 Years...                      0.015032
# Overall Rating                                                          0.101353
# Health Inspection Rating                                                0.103410
# Staffing Rating                                                         0.188538
# RN Staffing Rating                                                      0.161519
# Total Weighted Health Survey Score                                     -0.048840
# Number of Facility Reported Incidents                                  -0.025148
# Number of Substantiated Complaints                                     -0.099568
# Number of Fines                                                        -0.046814
# Number of Payment Denials                                              -0.018318
# Total Number of Penalties                                              -0.044554
# Adjusted Total Nurse Staffing Hours per Residen...                      0.242003
#
#                                                     Most Recent Health Inspection More Than 2 Years Ago  \
# Provider Zip Code                                                                            0.000004
# Number of Certified Beds                                                                    -0.026011
# Number of Residents in Certified Beds                                                       -0.024258
# Provider Resides in Hospital                                                                 0.015032
# Most Recent Health Inspection More Than 2 Years...                                           1.000000
# Overall Rating                                                                               0.000242
# Health Inspection Rating                                                                    -0.004956
# Staffing Rating                                                                              0.018877
# RN Staffing Rating                                                                           0.020911
# Total Weighted Health Survey Score                                                           0.020017
# Number of Facility Reported Incidents                                                       -0.008041
# Number of Substantiated Complaints                                                          -0.009028
# Number of Fines                                                                             -0.009638
# Number of Payment Denials                                                                   -0.000552
# Total Number of Penalties                                                                   -0.007984
# Adjusted Total Nurse Staffing Hours per Residen...                                           0.014354
#
#                                                     Overall Rating  \
# Provider Zip Code                                         0.011350
# Number of Certified Beds                                 -0.177076
# Number of Residents in Certified Beds                    -0.136609
# Provider Resides in Hospital                              0.101353
# Most Recent Health Inspection More Than 2 Years...        0.000242
# Overall Rating                                            1.000000
# Health Inspection Rating                                  0.839331
# Staffing Rating                                           0.466591
# RN Staffing Rating                                        0.426148
# Total Weighted Health Survey Score                       -0.552923
# Number of Facility Reported Incidents                    -0.174330
# Number of Substantiated Complaints                       -0.382881
# Number of Fines                                          -0.350939
# Number of Payment Denials                                -0.259359
# Total Number of Penalties                                -0.379139
# Adjusted Total Nurse Staffing Hours per Residen...        0.324305
#
#                                                     Health Inspection Rating  \
# Provider Zip Code                                                  -0.001988
# Number of Certified Beds                                           -0.169983
# Number of Residents in Certified Beds                              -0.133849
# Provider Resides in Hospital                                        0.103410
# Most Recent Health Inspection More Than 2 Years...                 -0.004956
# Overall Rating                                                      0.839331
# Health Inspection Rating                                            1.000000
# Staffing Rating                                                     0.183518
# RN Staffing Rating                                                  0.189953
# Total Weighted Health Survey Score                                 -0.614811
# Number of Facility Reported Incidents                              -0.225469
# Number of Substantiated Complaints                                 -0.413672
# Number of Fines                                                    -0.389060
# Number of Payment Denials                                          -0.274452
# Total Number of Penalties                                          -0.415490
# Adjusted Total Nurse Staffing Hours per Residen...                  0.158568
#
#                                                     Staffing Rating  \
# Provider Zip Code                                          0.019494
# Number of Certified Beds                                  -0.206938
# Number of Residents in Certified Beds                     -0.205556
# Provider Resides in Hospital                               0.188538
# Most Recent Health Inspection More Than 2 Years...         0.018877
# Overall Rating                                             0.466591
# Health Inspection Rating                                   0.183518
# Staffing Rating                                            1.000000
# RN Staffing Rating                                         0.797777
# Total Weighted Health Survey Score                        -0.144152
# Number of Facility Reported Incidents                      0.015987
# Number of Substantiated Complaints                        -0.148361
# Number of Fines                                           -0.067926
# Number of Payment Denials                                 -0.055061
# Total Number of Penalties                                 -0.075202
# Adjusted Total Nurse Staffing Hours per Residen...         0.693626
#
#                                                     RN Staffing Rating  \
# Provider Zip Code                                            -0.065033
# Number of Certified Beds                                     -0.205187
# Number of Residents in Certified Beds                        -0.198600
# Provider Resides in Hospital                                  0.161519
# Most Recent Health Inspection More Than 2 Years...            0.020911
# Overall Rating                                                0.426148
# Health Inspection Rating                                      0.189953
# Staffing Rating                                               0.797777
# RN Staffing Rating                                            1.000000
# Total Weighted Health Survey Score                           -0.172038
# Number of Facility Reported Incidents                         0.011355
# Number of Substantiated Complaints                           -0.132248
# Number of Fines                                              -0.083301
# Number of Payment Denials                                    -0.071549
# Total Number of Penalties                                    -0.093710
# Adjusted Total Nurse Staffing Hours per Residen...            0.419558
#
#                                                     Total Weighted Health Survey Score  \
# Provider Zip Code                                                             0.198754
# Number of Certified Beds                                                      0.078245
# Number of Residents in Certified Beds                                         0.028913
# Provider Resides in Hospital                                                 -0.048840
# Most Recent Health Inspection More Than 2 Years...                            0.020017
# Overall Rating                                                               -0.552923
# Health Inspection Rating                                                     -0.614811
# Staffing Rating                                                              -0.144152
# RN Staffing Rating                                                           -0.172038
# Total Weighted Health Survey Score                                            1.000000
# Number of Facility Reported Incidents                                         0.267858
# Number of Substantiated Complaints                                            0.418180
# Number of Fines                                                               0.409955
# Number of Payment Denials                                                     0.469694
# Total Number of Penalties                                                     0.504506
# Adjusted Total Nurse Staffing Hours per Residen...                           -0.080101
#
#                                                     Number of Facility Reported Incidents  \
# Provider Zip Code                                                                0.132162
# Number of Certified Beds                                                         0.091545
# Number of Residents in Certified Beds                                            0.082893
# Provider Resides in Hospital                                                    -0.025148
# Most Recent Health Inspection More Than 2 Years...                              -0.008041
# Overall Rating                                                                  -0.174330
# Health Inspection Rating                                                        -0.225469
# Staffing Rating                                                                  0.015987
# RN Staffing Rating                                                               0.011355
# Total Weighted Health Survey Score                                               0.267858
# Number of Facility Reported Incidents                                            1.000000
# Number of Substantiated Complaints                                               0.279316
# Number of Fines                                                                  0.174025
# Number of Payment Denials                                                        0.168167
# Total Number of Penalties                                                        0.202583
# Adjusted Total Nurse Staffing Hours per Residen...                              -0.012225
#
#                                                     Number of Substantiated Complaints  \
# Provider Zip Code                                                             0.084715
# Number of Certified Beds                                                      0.209582
# Number of Residents in Certified Beds                                         0.157475
# Provider Resides in Hospital                                                 -0.099568
# Most Recent Health Inspection More Than 2 Years...                           -0.009028
# Overall Rating                                                               -0.382881
# Health Inspection Rating                                                     -0.413672
# Staffing Rating                                                              -0.148361
# RN Staffing Rating                                                           -0.132248
# Total Weighted Health Survey Score                                            0.418180
# Number of Facility Reported Incidents                                         0.279316
# Number of Substantiated Complaints                                            1.000000
# Number of Fines                                                               0.272140
# Number of Payment Denials                                                     0.290037
# Total Number of Penalties                                                     0.326792
# Adjusted Total Nurse Staffing Hours per Residen...                           -0.135361
#
#                                                     Number of Fines  \
# Provider Zip Code                                          0.038334
# Number of Certified Beds                                   0.075043
# Number of Residents in Certified Beds                      0.043969
# Provider Resides in Hospital                              -0.046814
# Most Recent Health Inspection More Than 2 Years...        -0.009638
# Overall Rating                                            -0.350939
# Health Inspection Rating                                  -0.389060
# Staffing Rating                                           -0.067926
# RN Staffing Rating                                        -0.083301
# Total Weighted Health Survey Score                         0.409955
# Number of Facility Reported Incidents                      0.174025
# Number of Substantiated Complaints                         0.272140
# Number of Fines                                            1.000000
# Number of Payment Denials                                  0.355569
# Total Number of Penalties                                  0.938535
# Adjusted Total Nurse Staffing Hours per Residen...        -0.052368
#
#                                                     Number of Payment Denials  \
# Provider Zip Code                                                    0.114800
# Number of Certified Beds                                             0.029804
# Number of Residents in Certified Beds                               -0.011505
# Provider Resides in Hospital                                        -0.018318
# Most Recent Health Inspection More Than 2 Years...                  -0.000552
# Overall Rating                                                      -0.259359
# Health Inspection Rating                                            -0.274452
# Staffing Rating                                                     -0.055061
# RN Staffing Rating                                                  -0.071549
# Total Weighted Health Survey Score                                   0.469694
# Number of Facility Reported Incidents                                0.168167
# Number of Substantiated Complaints                                   0.290037
# Number of Fines                                                      0.355569
# Number of Payment Denials                                            1.000000
# Total Number of Penalties                                            0.656340
# Adjusted Total Nurse Staffing Hours per Residen...                  -0.021207
#
#                                                     Total Number of Penalties  \
# Provider Zip Code                                                    0.073342
# Number of Certified Beds                                             0.071583
# Number of Residents in Certified Beds                                0.031244
# Provider Resides in Hospital                                        -0.044554
# Most Recent Health Inspection More Than 2 Years...                  -0.007984
# Overall Rating                                                      -0.379139
# Health Inspection Rating                                            -0.415490
# Staffing Rating                                                     -0.075202
# RN Staffing Rating                                                  -0.093710
# Total Weighted Health Survey Score                                   0.504506
# Number of Facility Reported Incidents                                0.202583
# Number of Substantiated Complaints                                   0.326792
# Number of Fines                                                      0.938535
# Number of Payment Denials                                            0.656340
# Total Number of Penalties                                            1.000000
# Adjusted Total Nurse Staffing Hours per Residen...                  -0.050132
#
#                                                     Adjusted Total Nurse Staffing Hours per Resident per Day
# Provider Zip Code                                                                            0.092353
# Number of Certified Beds                                                                    -0.196783
# Number of Residents in Certified Beds                                                       -0.205458
# Provider Resides in Hospital                                                                 0.242003
# Most Recent Health Inspection More Than 2 Years...                                           0.014354
# Overall Rating                                                                               0.324305
# Health Inspection Rating                                                                     0.158568
# Staffing Rating                                                                              0.693626
# RN Staffing Rating                                                                           0.419558
# Total Weighted Health Survey Score                                                          -0.080101
# Number of Facility Reported Incidents                                                       -0.012225
# Number of Substantiated Complaints                                                          -0.135361
# Number of Fines                                                                             -0.052368
# Number of Payment Denials                                                                   -0.021207
# Total Number of Penalties                                                                   -0.050132
# Adjusted Total Nurse Staffing Hours per Residen...                                           1.000000

# %%
correlations_df.insert(0, 'Column Of Category', correlations_df.index)
correlations_df
# Out:
#                                                                                    Column Of Category  \
# Provider Zip Code                                                                   Provider Zip Code
# Number of Certified Beds                                                     Number of Certified Beds
# Number of Residents in Certified Beds                           Number of Residents in Certified Beds
# Provider Resides in Hospital                                             Provider Resides in Hospital
# Most Recent Health Inspection More Than 2 Years...  Most Recent Health Inspection More Than 2 Year...
# Overall Rating                                                                         Overall Rating
# Health Inspection Rating                                                     Health Inspection Rating
# Staffing Rating                                                                       Staffing Rating
# RN Staffing Rating                                                                 RN Staffing Rating
# Total Weighted Health Survey Score                                 Total Weighted Health Survey Score
# Number of Facility Reported Incidents                           Number of Facility Reported Incidents
# Number of Substantiated Complaints                                 Number of Substantiated Complaints
# Number of Fines                                                                       Number of Fines
# Number of Payment Denials                                                   Number of Payment Denials
# Total Number of Penalties                                                   Total Number of Penalties
# Adjusted Total Nurse Staffing Hours per Residen...  Adjusted Total Nurse Staffing Hours per Reside...
#
#                                                     Provider Zip Code  \
# Provider Zip Code                                            1.000000
# Number of Certified Beds                                    -0.175971
# Number of Residents in Certified Beds                       -0.246064
# Provider Resides in Hospital                                 0.022419
# Most Recent Health Inspection More Than 2 Years...           0.000004
# Overall Rating                                               0.011350
# Health Inspection Rating                                    -0.001988
# Staffing Rating                                              0.019494
# RN Staffing Rating                                          -0.065033
# Total Weighted Health Survey Score                           0.198754
# Number of Facility Reported Incidents                        0.132162
# Number of Substantiated Complaints                           0.084715
# Number of Fines                                              0.038334
# Number of Payment Denials                                    0.114800
# Total Number of Penalties                                    0.073342
# Adjusted Total Nurse Staffing Hours per Residen...           0.092353
#
#                                                     Number of Certified Beds  \
# Provider Zip Code                                                  -0.175971
# Number of Certified Beds                                            1.000000
# Number of Residents in Certified Beds                               0.923585
# Provider Resides in Hospital                                       -0.148536
# Most Recent Health Inspection More Than 2 Years...                 -0.026011
# Overall Rating                                                     -0.177076
# Health Inspection Rating                                           -0.169983
# Staffing Rating                                                    -0.206938
# RN Staffing Rating                                                 -0.205187
# Total Weighted Health Survey Score                                  0.078245
# Number of Facility Reported Incidents                               0.091545
# Number of Substantiated Complaints                                  0.209582
# Number of Fines                                                     0.075043
# Number of Payment Denials                                           0.029804
# Total Number of Penalties                                           0.071583
# Adjusted Total Nurse Staffing Hours per Residen...                 -0.196783
#
#                                                     Number of Residents in Certified Beds  \
# Provider Zip Code                                                               -0.246064
# Number of Certified Beds                                                         0.923585
# Number of Residents in Certified Beds                                            1.000000
# Provider Resides in Hospital                                                    -0.140992
# Most Recent Health Inspection More Than 2 Years...                              -0.024258
# Overall Rating                                                                  -0.136609
# Health Inspection Rating                                                        -0.133849
# Staffing Rating                                                                 -0.205556
# RN Staffing Rating                                                              -0.198600
# Total Weighted Health Survey Score                                               0.028913
# Number of Facility Reported Incidents                                            0.082893
# Number of Substantiated Complaints                                               0.157475
# Number of Fines                                                                  0.043969
# Number of Payment Denials                                                       -0.011505
# Total Number of Penalties                                                        0.031244
# Adjusted Total Nurse Staffing Hours per Residen...                              -0.205458
#
#                                                     Provider Resides in Hospital  \
# Provider Zip Code                                                       0.022419
# Number of Certified Beds                                               -0.148536
# Number of Residents in Certified Beds                                  -0.140992
# Provider Resides in Hospital                                            1.000000
# Most Recent Health Inspection More Than 2 Years...                      0.015032
# Overall Rating                                                          0.101353
# Health Inspection Rating                                                0.103410
# Staffing Rating                                                         0.188538
# RN Staffing Rating                                                      0.161519
# Total Weighted Health Survey Score                                     -0.048840
# Number of Facility Reported Incidents                                  -0.025148
# Number of Substantiated Complaints                                     -0.099568
# Number of Fines                                                        -0.046814
# Number of Payment Denials                                              -0.018318
# Total Number of Penalties                                              -0.044554
# Adjusted Total Nurse Staffing Hours per Residen...                      0.242003
#
#                                                     Most Recent Health Inspection More Than 2 Years Ago  \
# Provider Zip Code                                                                            0.000004
# Number of Certified Beds                                                                    -0.026011
# Number of Residents in Certified Beds                                                       -0.024258
# Provider Resides in Hospital                                                                 0.015032
# Most Recent Health Inspection More Than 2 Years...                                           1.000000
# Overall Rating                                                                               0.000242
# Health Inspection Rating                                                                    -0.004956
# Staffing Rating                                                                              0.018877
# RN Staffing Rating                                                                           0.020911
# Total Weighted Health Survey Score                                                           0.020017
# Number of Facility Reported Incidents                                                       -0.008041
# Number of Substantiated Complaints                                                          -0.009028
# Number of Fines                                                                             -0.009638
# Number of Payment Denials                                                                   -0.000552
# Total Number of Penalties                                                                   -0.007984
# Adjusted Total Nurse Staffing Hours per Residen...                                           0.014354
#
#                                                     Overall Rating  \
# Provider Zip Code                                         0.011350
# Number of Certified Beds                                 -0.177076
# Number of Residents in Certified Beds                    -0.136609
# Provider Resides in Hospital                              0.101353
# Most Recent Health Inspection More Than 2 Years...        0.000242
# Overall Rating                                            1.000000
# Health Inspection Rating                                  0.839331
# Staffing Rating                                           0.466591
# RN Staffing Rating                                        0.426148
# Total Weighted Health Survey Score                       -0.552923
# Number of Facility Reported Incidents                    -0.174330
# Number of Substantiated Complaints                       -0.382881
# Number of Fines                                          -0.350939
# Number of Payment Denials                                -0.259359
# Total Number of Penalties                                -0.379139
# Adjusted Total Nurse Staffing Hours per Residen...        0.324305
#
#                                                     Health Inspection Rating  \
# Provider Zip Code                                                  -0.001988
# Number of Certified Beds                                           -0.169983
# Number of Residents in Certified Beds                              -0.133849
# Provider Resides in Hospital                                        0.103410
# Most Recent Health Inspection More Than 2 Years...                 -0.004956
# Overall Rating                                                      0.839331
# Health Inspection Rating                                            1.000000
# Staffing Rating                                                     0.183518
# RN Staffing Rating                                                  0.189953
# Total Weighted Health Survey Score                                 -0.614811
# Number of Facility Reported Incidents                              -0.225469
# Number of Substantiated Complaints                                 -0.413672
# Number of Fines                                                    -0.389060
# Number of Payment Denials                                          -0.274452
# Total Number of Penalties                                          -0.415490
# Adjusted Total Nurse Staffing Hours per Residen...                  0.158568
#
#                                                     Staffing Rating  \
# Provider Zip Code                                          0.019494
# Number of Certified Beds                                  -0.206938
# Number of Residents in Certified Beds                     -0.205556
# Provider Resides in Hospital                               0.188538
# Most Recent Health Inspection More Than 2 Years...         0.018877
# Overall Rating                                             0.466591
# Health Inspection Rating                                   0.183518
# Staffing Rating                                            1.000000
# RN Staffing Rating                                         0.797777
# Total Weighted Health Survey Score                        -0.144152
# Number of Facility Reported Incidents                      0.015987
# Number of Substantiated Complaints                        -0.148361
# Number of Fines                                           -0.067926
# Number of Payment Denials                                 -0.055061
# Total Number of Penalties                                 -0.075202
# Adjusted Total Nurse Staffing Hours per Residen...         0.693626
#
#                                                     RN Staffing Rating  \
# Provider Zip Code                                            -0.065033
# Number of Certified Beds                                     -0.205187
# Number of Residents in Certified Beds                        -0.198600
# Provider Resides in Hospital                                  0.161519
# Most Recent Health Inspection More Than 2 Years...            0.020911
# Overall Rating                                                0.426148
# Health Inspection Rating                                      0.189953
# Staffing Rating                                               0.797777
# RN Staffing Rating                                            1.000000
# Total Weighted Health Survey Score                           -0.172038
# Number of Facility Reported Incidents                         0.011355
# Number of Substantiated Complaints                           -0.132248
# Number of Fines                                              -0.083301
# Number of Payment Denials                                    -0.071549
# Total Number of Penalties                                    -0.093710
# Adjusted Total Nurse Staffing Hours per Residen...            0.419558
#
#                                                     Total Weighted Health Survey Score  \
# Provider Zip Code                                                             0.198754
# Number of Certified Beds                                                      0.078245
# Number of Residents in Certified Beds                                         0.028913
# Provider Resides in Hospital                                                 -0.048840
# Most Recent Health Inspection More Than 2 Years...                            0.020017
# Overall Rating                                                               -0.552923
# Health Inspection Rating                                                     -0.614811
# Staffing Rating                                                              -0.144152
# RN Staffing Rating                                                           -0.172038
# Total Weighted Health Survey Score                                            1.000000
# Number of Facility Reported Incidents                                         0.267858
# Number of Substantiated Complaints                                            0.418180
# Number of Fines                                                               0.409955
# Number of Payment Denials                                                     0.469694
# Total Number of Penalties                                                     0.504506
# Adjusted Total Nurse Staffing Hours per Residen...                           -0.080101
#
#                                                     Number of Facility Reported Incidents  \
# Provider Zip Code                                                                0.132162
# Number of Certified Beds                                                         0.091545
# Number of Residents in Certified Beds                                            0.082893
# Provider Resides in Hospital                                                    -0.025148
# Most Recent Health Inspection More Than 2 Years...                              -0.008041
# Overall Rating                                                                  -0.174330
# Health Inspection Rating                                                        -0.225469
# Staffing Rating                                                                  0.015987
# RN Staffing Rating                                                               0.011355
# Total Weighted Health Survey Score                                               0.267858
# Number of Facility Reported Incidents                                            1.000000
# Number of Substantiated Complaints                                               0.279316
# Number of Fines                                                                  0.174025
# Number of Payment Denials                                                        0.168167
# Total Number of Penalties                                                        0.202583
# Adjusted Total Nurse Staffing Hours per Residen...                              -0.012225
#
#                                                     Number of Substantiated Complaints  \
# Provider Zip Code                                                             0.084715
# Number of Certified Beds                                                      0.209582
# Number of Residents in Certified Beds                                         0.157475
# Provider Resides in Hospital                                                 -0.099568
# Most Recent Health Inspection More Than 2 Years...                           -0.009028
# Overall Rating                                                               -0.382881
# Health Inspection Rating                                                     -0.413672
# Staffing Rating                                                              -0.148361
# RN Staffing Rating                                                           -0.132248
# Total Weighted Health Survey Score                                            0.418180
# Number of Facility Reported Incidents                                         0.279316
# Number of Substantiated Complaints                                            1.000000
# Number of Fines                                                               0.272140
# Number of Payment Denials                                                     0.290037
# Total Number of Penalties                                                     0.326792
# Adjusted Total Nurse Staffing Hours per Residen...                           -0.135361
#
#                                                     Number of Fines  \
# Provider Zip Code                                          0.038334
# Number of Certified Beds                                   0.075043
# Number of Residents in Certified Beds                      0.043969
# Provider Resides in Hospital                              -0.046814
# Most Recent Health Inspection More Than 2 Years...        -0.009638
# Overall Rating                                            -0.350939
# Health Inspection Rating                                  -0.389060
# Staffing Rating                                           -0.067926
# RN Staffing Rating                                        -0.083301
# Total Weighted Health Survey Score                         0.409955
# Number of Facility Reported Incidents                      0.174025
# Number of Substantiated Complaints                         0.272140
# Number of Fines                                            1.000000
# Number of Payment Denials                                  0.355569
# Total Number of Penalties                                  0.938535
# Adjusted Total Nurse Staffing Hours per Residen...        -0.052368
#
#                                                     Number of Payment Denials  \
# Provider Zip Code                                                    0.114800
# Number of Certified Beds                                             0.029804
# Number of Residents in Certified Beds                               -0.011505
# Provider Resides in Hospital                                        -0.018318
# Most Recent Health Inspection More Than 2 Years...                  -0.000552
# Overall Rating                                                      -0.259359
# Health Inspection Rating                                            -0.274452
# Staffing Rating                                                     -0.055061
# RN Staffing Rating                                                  -0.071549
# Total Weighted Health Survey Score                                   0.469694
# Number of Facility Reported Incidents                                0.168167
# Number of Substantiated Complaints                                   0.290037
# Number of Fines                                                      0.355569
# Number of Payment Denials                                            1.000000
# Total Number of Penalties                                            0.656340
# Adjusted Total Nurse Staffing Hours per Residen...                  -0.021207
#
#                                                     Total Number of Penalties  \
# Provider Zip Code                                                    0.073342
# Number of Certified Beds                                             0.071583
# Number of Residents in Certified Beds                                0.031244
# Provider Resides in Hospital                                        -0.044554
# Most Recent Health Inspection More Than 2 Years...                  -0.007984
# Overall Rating                                                      -0.379139
# Health Inspection Rating                                            -0.415490
# Staffing Rating                                                     -0.075202
# RN Staffing Rating                                                  -0.093710
# Total Weighted Health Survey Score                                   0.504506
# Number of Facility Reported Incidents                                0.202583
# Number of Substantiated Complaints                                   0.326792
# Number of Fines                                                      0.938535
# Number of Payment Denials                                            0.656340
# Total Number of Penalties                                            1.000000
# Adjusted Total Nurse Staffing Hours per Residen...                  -0.050132
#
#                                                     Adjusted Total Nurse Staffing Hours per Resident per Day
# Provider Zip Code                                                                            0.092353
# Number of Certified Beds                                                                    -0.196783
# Number of Residents in Certified Beds                                                       -0.205458
# Provider Resides in Hospital                                                                 0.242003
# Most Recent Health Inspection More Than 2 Years...                                           0.014354
# Overall Rating                                                                               0.324305
# Health Inspection Rating                                                                     0.158568
# Staffing Rating                                                                              0.693626
# RN Staffing Rating                                                                           0.419558
# Total Weighted Health Survey Score                                                          -0.080101
# Number of Facility Reported Incidents                                                       -0.012225
# Number of Substantiated Complaints                                                          -0.135361
# Number of Fines                                                                             -0.052368
# Number of Payment Denials                                                                   -0.021207
# Total Number of Penalties                                                                   -0.050132
# Adjusted Total Nurse Staffing Hours per Residen...                                           1.000000

# %%
# Save correlations to file
correlations_df.to_json('./correlations_df_by_record.json', orient='records')

# %%
# Create a saving point (for the loading point in the cell below)
truncated_nursing_df.to_json('./truncated_nursing_df1.json')
truncated_nursing_df.to_json('./truncated_nursing_df1_by_record.json', orient='records')
truncated_nursing_df.to_csv('./truncated_nursing_df1.csv', index=False)

# %%
# Create a loading point to skip all the previous cells when rerunning
# the code further past this cell
truncated_nursing_df = pd.read_csv('./truncated_nursing_df1.csv')

# %%
# Verify that the load of the data was successful
print(truncated_nursing_df.shape)
truncated_nursing_df.head()

# %%
# Create the a performance table
list_of_performance_columns_df = ['Most Recent Health Inspection More Than 2 Years Ago', 'Overall Rating',
       'Health Inspection Rating', 'Staffing Rating', 'RN Staffing Rating',
       'Total Weighted Health Survey Score',
       'Number of Facility Reported Incidents',
       'Number of Substantiated Complaints', 'Number of Fines',
       'Total Amount of Fines in Dollars', 'Number of Payment Denials',
       'Total Number of Penalties']

performance_table_df = pd.DataFrame()
performance_table_df[list_of_performance_columns_df] = truncated_nursing_df[list_of_performance_columns_df]

# Verify that the performance table was created
print(performance_table_df.shape)
performance_table_df.head()

# %%
# Show the number of rows in performance_table_df just before any duplicate rows are
# dropped to verify that rows were dropped.
performance_table_df.shape

# %%
# Remove dupulicate rows
performance_table_df.drop_duplicates(subset=list_of_performance_columns_df, inplace=True)

# %%
# Verify that rows were dropped.
print(performance_table_df.shape)

# %%
# Create a primary key for performance_table_df called 'performance_id'. 
performance_table_df['performance_id'] = [i for i in range(performance_table_df.shape[0])]

# Verify that 'performance_id' was created
print(performance_table_df.shape)
performance_table_df.head()

# %%
# Save performance table data to a .csv and .json (for the loading point in the cell below and 
# for data manipulations, respectively)
performance_table_df.to_csv('../TableData/performance_table.csv', index=False)
performance_table_df.to_json('../TableData/performance_table.json')

# %%
# Create a loading point to skip all the previous cells when rerunning
# the code further past this cell
performance_table_df = pd.read_csv('../TableData/performance_table.csv')

# %%
# Verify that the load of the data was successful
print(performance_table_df.shape)
performance_table_df.head()

# %%
# Show the shape of truncated_nursing_df just before adding a column for verification
# after the column is added
truncated_nursing_df.shape

# %%
# Add a column for the foreign key called performance_id in what will be used
# to create the business_table_df further below and initialize performance_id
# to an unused and recognizable value (-1)
truncated_nursing_df['performance_id'] = -1

# %%
# Verify that the column was added
print(truncated_nursing_df.shape)
truncated_nursing_df[['Provider Name', 'performance_id']]

# %%
# Add corrected performance_id foriegn key to truncated_nursing_df
for i in range(truncated_nursing_df.shape[0]):
    for j in range(performance_table_df.shape[0]):
        all_performance_columns_match = True
        for k in range(len(list_of_performance_columns_df)):

            # Must convert the value to str otherwise the 'nan' of truncated_nursing_df can't
            # match the 'nan' of performance_table_df
            if str(truncated_nursing_df[list_of_performance_columns_df[k]].iloc[i]) != str(performance_table_df[list_of_performance_columns_df[k]].iloc[j]):
                all_performance_columns_match = False
                break
        if  all_performance_columns_match:     
            truncated_nursing_df['performance_id'].iloc[i] = performance_table_df['performance_id'].iloc[j]
            break

# %%
# Verify that foreign keys 'perfomance_id' are no longer '-1'
print(len(truncated_nursing_df[truncated_nursing_df['performance_id'] != '-1']))
print(truncated_nursing_df.shape[0])
truncated_nursing_df[['Provider Name', 'performance_id']]

# %%
# Show that record 407 of the truncated table and row 16 of the performance table have the
# same values for the columns of performance table (list_of_performance_columns_df) and
# have the same performance_id (16) associated with them.
print(truncated_nursing_df[list_of_performance_columns_df].iloc[407])
print(f"performance_id for truncated is: {truncated_nursing_df['performance_id'].iloc[407]}")
performance_table_df.iloc[16]

# %%
# Show the shape of truncated_nursing_df before the save point to compare
# with its shape after the save point
truncated_nursing_df.shape

# %%
# Create a saving point (for the loading point in the cell below)
truncated_nursing_df.to_csv('./truncated_nursing_df2.csv', index=False)
truncated_nursing_df.to_json('./truncated_nursing_df2_by_record.json', orient='records')
truncated_nursing_df.to_json('./truncated_nursing_df2.json')

# %%
# Create a loading point to skip all the previous cells when rerunning
# the code further past this cell
truncated_nursing_df = pd.read_csv('./truncated_nursing_df2.csv')

# %%
# Verify that the load of the data was successful
print(truncated_nursing_df.shape)
truncated_nursing_df.head()

# %%
# Create the a business table
list_of_business_columns = ['Federal Provider Number', 'Provider Name', 
    'Provider City', 'Provider Zip Code', 'Provider County Name',
    'Ownership Type', 'Number of Certified Beds', 'Number of Residents in Certified Beds', 
    'Provider Type', 'Provider Resides in Hospital',  
    'Automatic Sprinkler Systems in All Required Areas', 'Location', 'Processing Date', 
    'Latitude','Longitude', 'Adjusted Total Nurse Staffing Hours per Resident per Day',
    'performance_id']
business_table_df = pd.DataFrame()
business_table_df[list_of_business_columns] = truncated_nursing_df[list_of_business_columns] 

# Verify that the business table was created
print(business_table_df.shape)
business_table_df.head()

# %%
# Save business table and create a saving point (for the loading point in the cell below)
business_table_df.to_csv('../TableData/business_table.csv', index=False)
business_table_df.to_json('../TableData/business_table.json')

# %%
# Create a loading point to skip all the previous cells when rerunning
# the code further past this cell
business_table_df = pd.read_csv('../TableData/business_table.csv')

# %%
# Verify that the load of the data was successful
print(business_table_df.shape)
business_table_df.head()

# %%
# Create a zipcode table
list_of_state_zipcodes = ['Provider State', 'Provider Zip Code']
zip_state_table_df = pd.DataFrame()
zip_state_table_df[list_of_state_zipcodes] = truncated_nursing_df[list_of_state_zipcodes]

# Verify that the load of the data was successful
print(zip_state_table_df.shape)
zip_state_table_df.head()

# %%
# Show number of rows before dropping the duplicates
print(zip_state_table_df.shape[0])

# %%
# Drop duplicate rows
zip_state_table_df.drop_duplicates(inplace=True)

# %%
# Verify that rows were dropped
print(zip_state_table_df.shape)
zip_state_table_df.head()

# %%
# Save zipcode table and create a saving point (for the loading point in the cell below)
zip_state_table_df.to_csv('../TableData/zipcode_table.csv', index=False)
zip_state_table_df.to_json('../TableData/zipcode_table.json')

# %%
# Create a loading point to skip all the previous cells when rerunning
# the code further past this cell
zip_state_table_df = pd.read_csv('../TableData/zipcode_table.csv')

# %%
# Verify that the load of the data was successful
print(zip_state_table_df.shape)
zip_state_table_df.head()
